# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train = np.loadtxt('age.csv', delimiter=",", skiprows=1)
train_x = train[:, 0]
train_y = train[:, 1]
plt.plot(train_x, train_y, 'o')

# %%
theta0 = np.random.rand()
theta1 = np.random.rand()
print(theta0, theta1)

def f(x):
    return theta0 + theta1 * x

def E(x, y):
    return 0.5 * np.sum((y - f(x)) ** 2)
# Out:
# (0.09771181135292284, 0.519112137009489)

# %%
mu = train_x.mean()
sigma = train_x.std()
def standardize(x):
    return (x - mu) / sigma

# %%
train_z = standardize(train_x)
plt.plot(train_z, train_y, "o")

# %%
ETA = 1e-2
diff = 1
count = 0
error = E(train_z, train_y)
while diff > 1e-2:
    tmp0 = theta0 - ETA * np.sum((f(train_z) - train_y))
    tmp1 = theta1 - ETA * np.sum((f(train_z) - train_y) * train_z)
    theta0 = tmp0
    theta1 = tmp1
    current_error = E(train_z, train_y)
    diff = error - current_error
    error = current_error
    count += 1
    log = 'No.{}: theta0 = {:.3f}, theta1 = {:.3f}, diff = {:.4f}'
    print(log.format(count, theta0, theta1, diff))
# Out:
# No.1: theta0 = 5412.151, theta1 = 1300.952, diff = 0.0934
# No.2: theta0 = 5412.179, theta1 = 1300.959, diff = 0.0791
# No.3: theta0 = 5412.205, theta1 = 1300.965, diff = 0.0669
# No.4: theta0 = 5412.228, theta1 = 1300.970, diff = 0.0566
# No.5: theta0 = 5412.250, theta1 = 1300.976, diff = 0.0479
# No.6: theta0 = 5412.270, theta1 = 1300.980, diff = 0.0406
# No.7: theta0 = 5412.289, theta1 = 1300.985, diff = 0.0343
# No.8: theta0 = 5412.305, theta1 = 1300.989, diff = 0.0291
# No.9: theta0 = 5412.321, theta1 = 1300.993, diff = 0.0246
# No.10: theta0 = 5412.335, theta1 = 1300.996, diff = 0.0208
# No.11: theta0 = 5412.348, theta1 = 1300.999, diff = 0.0176
# No.12: theta0 = 5412.361, theta1 = 1301.002, diff = 0.0149
# No.13: theta0 = 5412.372, theta1 = 1301.005, diff = 0.0126
# No.14: theta0 = 5412.382, theta1 = 1301.007, diff = 0.0107
# No.15: theta0 = 5412.391, theta1 = 1301.010, diff = 0.0090

# %%
x = np.linspace(-3, 3)
plt.plot(train_z, train_y, "o")
plt.plot(x, f(x))

# %%
f(standardize(10))
# Out:
# 270.82972354658523

# %%
f(standardize(50))
# Out:
# 9069.2241306574451
